# %% [markdown]
# # Testing the model without a magnetic field

# %% [markdown]
# ## setup

# %%
include("../src/ising.jl")
using CairoMakie

# %% [markdown]
# ## temperature sweeps

# %% [markdown]
# ### 1x1x1 grid

# %%
grid_size = 1
J= 1.0
energies, magnetisations, temps = temp_sweep(grid_size=grid_size,J=J)

fig = Figure()
scatter(fig[1, 1], temps, energies, color=:blue, label="Energy")
scatter(fig[2, 1], temps, magnetisations, color=:red, label="Magnetisation")
fig

# %% [markdown]
# ### 3x3x3 grid

# %%
grid_size = 3
J= 1.0
energies, magnetisations, temps = temp_sweep(grid_size=grid_size,J=J)

fig = Figure()
scatter(fig[1, 1], temps, energies, color=:blue, label="Energy")
scatter(fig[2, 1], temps, magnetisations, color=:red, label="Magnetisation")
fig

# %% [markdown]
# ### 5x5x5 grid

# %%
grid_size = 5
J= 1.0
energies, magnetisations, temps = temp_sweep(grid_size=grid_size,J=J)
fig = Figure()
scatter(fig[1, 1], temps, energies, color=:blue, label="Energy")
scatter(fig[2, 1], temps, magnetisations, color=:red, label="Magnetisation")
fig

# %% [markdown]
# ### 10x10x10 grid

# %%
grid_size = 10
J= 1.0
energies, magnetisations, temps = temp_sweep(grid_size=grid_size,J=J)
fig = Figure()
scatter(fig[1, 1], temps, energies, color=:blue, label="Energy")
scatter(fig[2, 1], temps, magnetisations, color=:red, label="Magnetisation")
fig
